# %% [markdown]
# # 22 : 378

# %%
import os, glob, pickle, time
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam, SGD


from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle

import matplotlib.pyplot as plt

from tqdm import tqdm_notebook

import sys
path = os.path.abspath('../../')
print(path)
sys.path.append(path)
from CommonUtil import *

path = os.path.abspath('./TF-1D-2D-ResNetV1-2-SEResNet-ResNeXt-SEResNeXt-main/Codes')
print(path)
sys.path.append(path)
import ResNet_1DCNN as res1d
import SE_ResNeXt_1DCNN as se_resx1d

#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_VISIBLE_DEVICES"]='0'
# os.environ["CUDA_VISIBLE_DEVICES"]='2'
#mirrored_strategy = tf.distribute.MirroredStrategy()
# Out:
# /home/gil/gcubme_ai3/Workspace/SB_MUN
# /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/TF-1D-2D-ResNetV1-2-SEResNet-ResNeXt-SEResNeXt-main/Codes

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
LEARNING_RATE = 1e-4
EPOCHS = 200
BATCH_SIZE = 4
MODEL_NUM = 4
LOSS_FUNCTION = tf.keras.losses.MeanAbsoluteError()
LOSS_FUNCTION = 'binary_crossentropy'
METRICS = tf.keras.metrics.MeanSquaredError()
METRICS = ['accuracy']

TRAIN_SPLIT = 17
# Out:
# 2024-01-13 22:36:30.283021: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-13 22:36:30.862878: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22325 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:3b:00.0, compute capability: 8.6

# %%
length = 64000
model_name = 'SEResNeXt'  # Modified DenseNet
model_width = 32  # Width of the Initial Layer, subsequent layers start from here
num_channel = 1  # Number of Channels in the Model
problem_type = 'Binary' # Classification or Regression
output_nums = 1  # Number of Class for Classification Problems, always '1' for Regression Problems
cardinality = 8
reduction_ratio = 4
# Build, Compile and Print Summary

# %%
DATA_PATH = os.path.abspath('./data/preproc2')
RESULT_DIR = os.path.abspath(f'./result/{model_name}')
MODEL_DIR = RESULT_DIR + '/model'

best_model_path = MODEL_DIR + '/best_model.h5'
model_path = MODEL_DIR + '/model.h5'

createFolder(MODEL_DIR)

print(DATA_PATH)
print(MODEL_DIR)
# Out:
# /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/data/preproc2
# /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/result/SEResNeXt/model

# %%
train_X_csv_list = sorted(glob.glob(f'{DATA_PATH}/train/*.csv'))
validation_X_csv_list = sorted(glob.glob(f'{DATA_PATH}/validation/*.csv'))

print(len(train_X_csv_list))
print(len(validation_X_csv_list))
# Out:
# 20000
# 2500

# %%
train_X_npy_list = [csv_path.split('.csv')[0] + '_X.npy' for csv_path in train_X_csv_list]
train_Y_npy_list = [csv_path.split('.csv')[0] + '_Y.npy' for csv_path in train_X_csv_list]
validation_X_npy_list = [csv_path.split('.csv')[0] + '_X.npy' for csv_path in validation_X_csv_list]
validation_Y_npy_list = [csv_path.split('.csv')[0] + '_Y.npy' for csv_path in validation_X_csv_list]

# %%
train_X_npy_list, train_Y_npy_list = shuffle(train_X_npy_list, train_Y_npy_list)
validation_X_npy_list, validation_Y_npy_list = shuffle(validation_X_npy_list, validation_Y_npy_list)

# %%
def npy_load(X_path_list:list, Y_path_list:list):
    print(f'Total data len : {len(X_path_list)}')
    
    X_data = []
    Y_data = []
    data_paths = []
    
    for a in tqdm_notebook(range(len(X_path_list))):
#     for a in range(5):
        X_path = X_path_list[a]
        Y_path = Y_path_list[a]
    
#         print(f'{a}/{len(X_path_list)}\t==> {X_path}')
        
        X_npy = np.load(X_path)
        Y_npy = np.load(Y_path)
    
        X_data.extend(X_npy)
        Y_data.extend(Y_npy)
        data_paths.append(X_path)
        
    X_data, Y_data = shuffle(X_data, Y_data)
    
    X_data = np.array(X_data)
    Y_data = np.array(Y_data)
    X_data = np.expand_dims(X_data, axis=-1)
    Y_data = np.expand_dims(Y_data, axis=-1)
    print("X_data shape: ", X_data.shape, "\t Y_data shape: ", Y_data.shape)
    
    return X_data, Y_data # ,data_paths

# %%
train_X, train_Y = npy_load(train_X_npy_list, train_Y_npy_list)
validation_X, validation_Y = npy_load(validation_X_npy_list, validation_Y_npy_list)
# Out:
# Total data len : 20000
#   0%|          | 0/20000 [00:00<?, ?it/s]
# X_data shape:  (37407, 64000, 1) 	 Y_data shape:  (37407, 1)
# Total data len : 2500
#   0%|          | 0/2500 [00:00<?, ?it/s]
# X_data shape:  (4801, 64000, 1) 	 Y_data shape:  (4801, 1)

# %%
print(list(train_Y).count(0))
print(list(train_Y).count(1))
print('='*50)
print(list(validation_Y).count(0))
print(list(validation_Y).count(1))
print('='*50)
# Out:
# 24462
# 12945
# ==================================================
# 2889
# 1912
# ==================================================

# %% [markdown]
# # Model load

# %%
model = se_resx1d.SEResNeXt(length, num_channel, model_width, cardinality=cardinality, ratio=reduction_ratio,
                  problem_type=problem_type, output_nums=output_nums, pooling='avg', dropout_rate=False).SEResNeXt18()
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE), loss=LOSS_FUNCTION, metrics=METRICS)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64000, 1)]   0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 32000, 32)    256         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32000, 32)    128         conv1d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32000, 32)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 16000, 32)    0           activation[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 16000, 4)     0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 16000, 4)     0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 16000, 4)     0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 16000, 4)     0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 16000, 4)     0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 16000, 4)     0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 16000, 4)     0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 16000, 4)     0           max_pooling1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 16000, 32)    160         lambda[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 16000, 32)    160         lambda_1[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 16000, 32)    160         lambda_2[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 16000, 32)    160         lambda_3[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 16000, 32)    160         lambda_4[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 16000, 32)    160         lambda_5[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 16000, 32)    160         lambda_6[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 16000, 32)    160         lambda_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16000, 32)    128         conv1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16000, 32)    128         conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16000, 32)    128         conv1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16000, 32)    128         conv1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 16000, 32)    128         conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 16000, 32)    128         conv1d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 16000, 32)    128         conv1d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16000, 32)    128         conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16000, 32)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16000, 32)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16000, 32)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16000, 32)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 16000, 32)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 16000, 32)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 16000, 32)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16000, 32)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 16000, 4)     388         activation_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 16000, 4)     388         activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 16000, 4)     388         activation_6[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 16000, 4)     388         activation_8[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 16000, 4)     388         activation_10[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 16000, 4)     388         activation_12[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 16000, 4)     388         activation_14[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 16000, 4)     388         activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16000, 4)     16          conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16000, 4)     16          conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16000, 4)     16          conv1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16000, 4)     16          conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 16000, 4)     16          conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 16000, 4)     16          conv1d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16000, 4)     16          conv1d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16000, 4)     16          conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16000, 4)     0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16000, 4)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16000, 4)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 16000, 4)     0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 16000, 4)     0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 16000, 4)     0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16000, 4)     0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16000, 4)     0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 16000, 32)    0           activation_3[0][0]
#                                                                  activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_9[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16000, 32)    128         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16000, 32)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 32)           0           activation_18[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 8)            264         global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 8)            0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 32)           288         activation_19[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 32)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 32)        0           activation_20[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 16000, 32)    0           activation_18[0][0]
#                                                                  reshape[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 16000, 64)    2112        tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 16000, 64)    2112        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16000, 64)    256         conv1d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16000, 64)    256         conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16000, 64)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 16000, 64)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16000, 64)    0           activation_21[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16000, 64)    0           add[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 16000, 4)     0           activation_22[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 16000, 4)     0           activation_22[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 16000, 4)     0           activation_22[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 16000, 4)     0           activation_22[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 16000, 4)     0           activation_22[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 16000, 4)     0           activation_22[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 16000, 4)     0           activation_22[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 16000, 4)     0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 16000, 32)    160         lambda_8[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 16000, 32)    160         lambda_9[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 16000, 32)    160         lambda_10[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 16000, 32)    160         lambda_11[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 16000, 32)    160         lambda_12[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 16000, 32)    160         lambda_13[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 16000, 32)    160         lambda_14[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 16000, 32)    160         lambda_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16000, 32)    128         conv1d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16000, 32)    128         conv1d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16000, 32)    128         conv1d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16000, 32)    128         conv1d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16000, 32)    128         conv1d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16000, 32)    128         conv1d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 16000, 32)    128         conv1d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16000, 32)    128         conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16000, 32)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16000, 32)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16000, 32)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16000, 32)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 16000, 32)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 16000, 32)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16000, 32)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16000, 32)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 16000, 4)     388         activation_24[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 16000, 4)     388         activation_26[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 16000, 4)     388         activation_28[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 16000, 4)     388         activation_30[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 16000, 4)     388         activation_32[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 16000, 4)     388         activation_34[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 16000, 4)     388         activation_36[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 16000, 4)     388         activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16000, 4)     16          conv1d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16000, 4)     16          conv1d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16000, 4)     16          conv1d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16000, 4)     16          conv1d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16000, 4)     16          conv1d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 16000, 4)     16          conv1d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 16000, 4)     16          conv1d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 16000, 4)     16          conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16000, 4)     0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16000, 4)     0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16000, 4)     0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 16000, 4)     0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 16000, 4)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16000, 4)     0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16000, 4)     0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 16000, 4)     0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16000, 32)    0           activation_25[0][0]
#                                                                  activation_27[0][0]
#                                                                  activation_29[0][0]
#                                                                  activation_31[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_35[0][0]
#                                                                  activation_37[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 16000, 32)    128         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 16000, 32)    0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 32)           0           activation_40[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            264         global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 8)            0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           288         activation_41[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 32)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 32)        0           activation_42[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_1 (TFOpLambda) (None, 16000, 32)    0           activation_40[0][0]
#                                                                  reshape_1[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 16000, 64)    2112        tf.math.multiply_1[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 16000, 64)    4160        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 16000, 64)    256         conv1d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16000, 64)    256         conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 16000, 64)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16000, 64)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 16000, 64)    0           activation_43[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 16000, 64)    0           add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 8000, 64)     12352       activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8000, 64)     256         conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8000, 64)     0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 8000, 64)     12352       activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8000, 64)     256         conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 8000, 64)     0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 8000, 8)      0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 8000, 8)      0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 8000, 8)      0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 8000, 8)      0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 8000, 8)      0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 8000, 8)      0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 8000, 8)      0           activation_46[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 8000, 8)      0           activation_46[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 8000, 64)     576         lambda_16[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 8000, 64)     576         lambda_17[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 8000, 64)     576         lambda_18[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 8000, 64)     576         lambda_19[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 8000, 64)     576         lambda_20[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 8000, 64)     576         lambda_21[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 8000, 64)     576         lambda_22[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 8000, 64)     576         lambda_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8000, 64)     256         conv1d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 8000, 64)     256         conv1d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 8000, 64)     256         conv1d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 8000, 64)     256         conv1d_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 8000, 64)     256         conv1d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 8000, 64)     256         conv1d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 8000, 64)     256         conv1d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 8000, 64)     256         conv1d_54[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 8000, 64)     0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 8000, 64)     0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 8000, 64)     0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 8000, 64)     0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 8000, 64)     0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 8000, 64)     0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 8000, 64)     0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 8000, 64)     0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 8000, 8)      1544        activation_48[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 8000, 8)      1544        activation_50[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 8000, 8)      1544        activation_52[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 8000, 8)      1544        activation_54[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 8000, 8)      1544        activation_56[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 8000, 8)      1544        activation_58[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 8000, 8)      1544        activation_60[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 8000, 8)      1544        activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 8000, 8)      32          conv1d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8000, 8)      32          conv1d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 8000, 8)      32          conv1d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 8000, 8)      32          conv1d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 8000, 8)      32          conv1d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 8000, 8)      32          conv1d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 8000, 8)      32          conv1d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 8000, 8)      32          conv1d_55[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 8000, 8)      0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 8000, 8)      0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 8000, 8)      0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 8000, 8)      0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 8000, 8)      0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 8000, 8)      0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 8000, 8)      0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 8000, 8)      0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8000, 64)     0           activation_49[0][0]
#                                                                  activation_51[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_55[0][0]
#                                                                  activation_57[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_61[0][0]
#                                                                  activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 8000, 64)     256         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 8000, 64)     0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 64)           0           activation_64[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 16)           1040        global_average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 16)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           1088        activation_65[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 64)           0           dense_5[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 1, 64)        0           activation_66[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_2 (TFOpLambda) (None, 8000, 64)     0           activation_64[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, 8000, 128)    8320        tf.math.multiply_2[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 8000, 128)    8320        activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 8000, 128)    512         conv1d_56[0][0]
# ...
# lambda_34 (Lambda)              (None, 2000, 32)     0           activation_94[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 2000, 32)     0           activation_94[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 2000, 32)     0           activation_94[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 2000, 32)     0           activation_94[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 2000, 32)     0           activation_94[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 2000, 32)     0           activation_94[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 2000, 256)    8448        lambda_32[0][0]
# __________________________________________________________________________________________________
# conv1d_82 (Conv1D)              (None, 2000, 256)    8448        lambda_33[0][0]
# __________________________________________________________________________________________________
# conv1d_84 (Conv1D)              (None, 2000, 256)    8448        lambda_34[0][0]
# __________________________________________________________________________________________________
# conv1d_86 (Conv1D)              (None, 2000, 256)    8448        lambda_35[0][0]
# __________________________________________________________________________________________________
# conv1d_88 (Conv1D)              (None, 2000, 256)    8448        lambda_36[0][0]
# __________________________________________________________________________________________________
# conv1d_90 (Conv1D)              (None, 2000, 256)    8448        lambda_37[0][0]
# __________________________________________________________________________________________________
# conv1d_92 (Conv1D)              (None, 2000, 256)    8448        lambda_38[0][0]
# __________________________________________________________________________________________________
# conv1d_94 (Conv1D)              (None, 2000, 256)    8448        lambda_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 2000, 256)    1024        conv1d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 2000, 256)    1024        conv1d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 2000, 256)    1024        conv1d_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 2000, 256)    1024        conv1d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 2000, 256)    1024        conv1d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 2000, 256)    1024        conv1d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 2000, 256)    1024        conv1d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 2000, 256)    1024        conv1d_94[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 2000, 256)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 2000, 256)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 2000, 256)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 2000, 256)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 2000, 256)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 2000, 256)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 2000, 256)    0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 2000, 256)    0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv1d_81 (Conv1D)              (None, 2000, 32)     24608       activation_96[0][0]
# __________________________________________________________________________________________________
# conv1d_83 (Conv1D)              (None, 2000, 32)     24608       activation_98[0][0]
# __________________________________________________________________________________________________
# conv1d_85 (Conv1D)              (None, 2000, 32)     24608       activation_100[0][0]
# __________________________________________________________________________________________________
# conv1d_87 (Conv1D)              (None, 2000, 32)     24608       activation_102[0][0]
# __________________________________________________________________________________________________
# conv1d_89 (Conv1D)              (None, 2000, 32)     24608       activation_104[0][0]
# __________________________________________________________________________________________________
# conv1d_91 (Conv1D)              (None, 2000, 32)     24608       activation_106[0][0]
# __________________________________________________________________________________________________
# conv1d_93 (Conv1D)              (None, 2000, 32)     24608       activation_108[0][0]
# __________________________________________________________________________________________________
# conv1d_95 (Conv1D)              (None, 2000, 32)     24608       activation_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 2000, 32)     128         conv1d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 2000, 32)     128         conv1d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 2000, 32)     128         conv1d_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 2000, 32)     128         conv1d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 2000, 32)     128         conv1d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 2000, 32)     128         conv1d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 2000, 32)     128         conv1d_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 2000, 32)     128         conv1d_95[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 2000, 32)     0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 2000, 32)     0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 2000, 32)     0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 2000, 32)     0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 2000, 32)     0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 2000, 32)     0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 2000, 32)     0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 2000, 32)     0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 2000, 256)    0           activation_97[0][0]
#                                                                  activation_99[0][0]
#                                                                  activation_101[0][0]
#                                                                  activation_103[0][0]
#                                                                  activation_105[0][0]
#                                                                  activation_107[0][0]
#                                                                  activation_109[0][0]
#                                                                  activation_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 2000, 256)    1024        concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 2000, 256)    0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_4 (Glo (None, 256)          0           activation_112[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           16448       global_average_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 64)           0           dense_8[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 256)          16640       activation_113[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 256)          0           dense_9[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 1, 256)       0           activation_114[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply_4 (TFOpLambda) (None, 2000, 256)    0           activation_112[0][0]
#                                                                  reshape_4[0][0]
# __________________________________________________________________________________________________
# conv1d_96 (Conv1D)              (None, 2000, 512)    131584      tf.math.multiply_4[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 2000, 512)    131584      activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 2000, 512)    2048        conv1d_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 2000, 512)    2048        conv1d_79[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 2000, 512)    0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 2000, 512)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 2000, 512)    0           activation_115[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 2000, 512)    0           add_4[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_5 (Glo (None, 512)          0           activation_116[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 512)          0           global_average_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1)            513         flatten[0][0]
# ==================================================================================================
# Total params: 1,308,033
# Trainable params: 1,291,841
# Non-trainable params: 16,192
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, History, ReduceLROnPlateau, EarlyStopping

checkpointer = ModelCheckpoint(best_model_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, min_delta=1e-8)
earlystopper = EarlyStopping(monitor='val_loss', patience=30, verbose=1)
callbacks_list = [reduce_lr, checkpointer, earlystopper]

# %% [markdown]
# # train

# %%
from datetime import datetime
startTime = datetime.now()

print('Start Time : {0}'.format(startTime))
###############################################################################################

hist = model.fit(train_X, train_Y, 
                 batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=1, 
                 validation_data = (validation_X, validation_Y), 
                 callbacks=callbacks_list)

################################################################################################

endTime = datetime.now()
runTime = endTime - startTime

print('End Time : {0}'.format(endTime))
print('Running Time : ' + str(runTime))

print('Done training')
# Out:
# Start Time : 2024-01-13 22:41:45.517939
# 2024-01-13 22:41:45.524400: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 9576192000 exceeds 10% of free system memory.
# 2024-01-13 22:41:53.473846: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 9576192000 exceeds 10% of free system memory.
# 2024-01-13 22:41:58.971070: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2024-01-13 22:42:16.073778: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8201
# 2024-01-13 22:42:18.177063: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 9352/9352 [==============================] - 1137s 119ms/step - loss: 1.1327 - accuracy: 0.8185 - val_loss: 3.9999 - val_accuracy: 0.5095
#
# Epoch 00001: val_loss improved from inf to 3.99992, saving model to /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/result/SEResNeXt/model/best_model.h5
# /data01/anaconda3/envs/mab_dental2/lib/python3.7/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# 9352/9352 [==============================] - 1109s 119ms/step - loss: 2.0392 - accuracy: 0.8081 - val_loss: 9.1762 - val_accuracy: 0.3983
#
# Epoch 00002: val_loss did not improve from 3.99992
# Epoch 3/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 1.5578 - accuracy: 0.8410 - val_loss: 9.1686 - val_accuracy: 0.3983
#
# Epoch 00003: val_loss did not improve from 3.99992
# Epoch 4/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.3707 - accuracy: 0.9114 - val_loss: 3.5320 - val_accuracy: 0.5972
#
# Epoch 00004: val_loss improved from 3.99992 to 3.53199, saving model to /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/result/SEResNeXt/model/best_model.h5
# Epoch 5/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.2734 - accuracy: 0.9323 - val_loss: 9.1735 - val_accuracy: 0.3983
#
# Epoch 00005: val_loss did not improve from 3.53199
# Epoch 6/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.2454 - accuracy: 0.9421 - val_loss: 8.8518 - val_accuracy: 0.4091
#
# Epoch 00006: val_loss did not improve from 3.53199
# Epoch 7/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.4632 - accuracy: 0.9281 - val_loss: 0.1922 - val_accuracy: 0.9525
#
# Epoch 00007: val_loss improved from 3.53199 to 0.19220, saving model to /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/result/SEResNeXt/model/best_model.h5
# Epoch 8/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.2556 - accuracy: 0.9440 - val_loss: 0.3056 - val_accuracy: 0.9044
#
# Epoch 00008: val_loss did not improve from 0.19220
# Epoch 9/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.3101 - accuracy: 0.9363 - val_loss: 9.1549 - val_accuracy: 0.3978
#
# Epoch 00009: val_loss did not improve from 0.19220
# Epoch 10/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.1868 - accuracy: 0.9552 - val_loss: 9.1455 - val_accuracy: 0.3983
#
# Epoch 00010: val_loss did not improve from 0.19220
# Epoch 11/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.4261 - accuracy: 0.9263 - val_loss: 0.3186 - val_accuracy: 0.8948
#
# Epoch 00011: val_loss did not improve from 0.19220
# Epoch 12/200
# 9352/9352 [==============================] - 1105s 118ms/step - loss: 0.2115 - accuracy: 0.9455 - val_loss: 0.1453 - val_accuracy: 0.9579
#
# Epoch 00012: val_loss improved from 0.19220 to 0.14531, saving model to /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/result/SEResNeXt/model/best_model.h5
# Epoch 13/200
# 9352/9352 [==============================] - 1107s 118ms/step - loss: 0.2366 - accuracy: 0.9462 - val_loss: 0.5309 - val_accuracy: 0.8275
#
# Epoch 00013: val_loss did not improve from 0.14531
# Epoch 14/200
# 9352/9352 [==============================] - 1108s 118ms/step - loss: 0.2759 - accuracy: 0.9441 - val_loss: 0.2189 - val_accuracy: 0.9502
#
# Epoch 00014: val_loss did not improve from 0.14531
# Epoch 15/200
# 9352/9352 [==============================] - 1105s 118ms/step - loss: 0.1723 - accuracy: 0.9576 - val_loss: 0.2836 - val_accuracy: 0.9106
#
# Epoch 00015: val_loss did not improve from 0.14531
# Epoch 16/200
# 9352/9352 [==============================] - 1107s 118ms/step - loss: 0.2111 - accuracy: 0.9516 - val_loss: 0.2371 - val_accuracy: 0.9321
#
# Epoch 00016: val_loss did not improve from 0.14531
# Epoch 17/200
# 9352/9352 [==============================] - 1104s 118ms/step - loss: 0.2080 - accuracy: 0.9538 - val_loss: 0.1553 - val_accuracy: 0.9608
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00017: val_loss did not improve from 0.14531
# Epoch 18/200
# 9352/9352 [==============================] - 1108s 118ms/step - loss: 0.1162 - accuracy: 0.9753 - val_loss: 0.1456 - val_accuracy: 0.9681
#
# Epoch 00018: val_loss did not improve from 0.14531
# Epoch 19/200
# 9352/9352 [==============================] - 1105s 118ms/step - loss: 0.1104 - accuracy: 0.9757 - val_loss: 0.1632 - val_accuracy: 0.9679
#
# Epoch 00019: val_loss did not improve from 0.14531
# Epoch 20/200
# 9352/9352 [==============================] - 1109s 119ms/step - loss: 0.1040 - accuracy: 0.9763 - val_loss: 0.1684 - val_accuracy: 0.9608
#
# Epoch 00020: val_loss did not improve from 0.14531
# Epoch 21/200
# 9352/9352 [==============================] - 1105s 118ms/step - loss: 0.1098 - accuracy: 0.9751 - val_loss: 0.1375 - val_accuracy: 0.9633
#
# Epoch 00021: val_loss improved from 0.14531 to 0.13754, saving model to /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/result/SEResNeXt/model/best_model.h5
# Epoch 22/200
# 9352/9352 [==============================] - 1109s 119ms/step - loss: 0.1039 - accuracy: 0.9755 - val_loss: 0.1218 - val_accuracy: 0.9692
#
# Epoch 00022: val_loss improved from 0.13754 to 0.12176, saving model to /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/result/SEResNeXt/model/best_model.h5
# Epoch 23/200
# 9352/9352 [==============================] - 1110s 119ms/step - loss: 0.0971 - accuracy: 0.9762 - val_loss: 0.1342 - val_accuracy: 0.9646
#
# Epoch 00023: val_loss did not improve from 0.12176
# Epoch 24/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.0967 - accuracy: 0.9778 - val_loss: 0.1477 - val_accuracy: 0.9690
#
# Epoch 00024: val_loss did not improve from 0.12176
# Epoch 25/200
# 9352/9352 [==============================] - 1105s 118ms/step - loss: 0.1002 - accuracy: 0.9786 - val_loss: 0.1348 - val_accuracy: 0.9700
#
# Epoch 00025: val_loss did not improve from 0.12176
# Epoch 26/200
# 9352/9352 [==============================] - 1104s 118ms/step - loss: 0.0939 - accuracy: 0.9795 - val_loss: 0.1491 - val_accuracy: 0.9683
#
# Epoch 00026: val_loss did not improve from 0.12176
# Epoch 27/200
# 9352/9352 [==============================] - 1110s 119ms/step - loss: 0.0965 - accuracy: 0.9800 - val_loss: 0.1498 - val_accuracy: 0.9677
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00027: val_loss did not improve from 0.12176
# Epoch 28/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.0934 - accuracy: 0.9810 - val_loss: 0.1484 - val_accuracy: 0.9698
#
# Epoch 00028: val_loss did not improve from 0.12176
# Epoch 29/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.0911 - accuracy: 0.9810 - val_loss: 0.1516 - val_accuracy: 0.9704
#
# Epoch 00029: val_loss did not improve from 0.12176
# Epoch 30/200
# 9352/9352 [==============================] - 1105s 118ms/step - loss: 0.0898 - accuracy: 0.9810 - val_loss: 0.1493 - val_accuracy: 0.9690
#
# Epoch 00030: val_loss did not improve from 0.12176
# Epoch 31/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.0884 - accuracy: 0.9810 - val_loss: 0.1497 - val_accuracy: 0.9692
#
# Epoch 00031: val_loss did not improve from 0.12176
# Epoch 32/200
# 9352/9352 [==============================] - 1108s 118ms/step - loss: 0.0926 - accuracy: 0.9812 - val_loss: 0.1538 - val_accuracy: 0.9706
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 00032: val_loss did not improve from 0.12176
# Epoch 33/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.0862 - accuracy: 0.9820 - val_loss: 0.1521 - val_accuracy: 0.9700
#
# Epoch 00033: val_loss did not improve from 0.12176
# Epoch 34/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.0888 - accuracy: 0.9811 - val_loss: 0.1543 - val_accuracy: 0.9698
#
# Epoch 00034: val_loss did not improve from 0.12176
# Epoch 35/200
# 9352/9352 [==============================] - 1107s 118ms/step - loss: 0.0896 - accuracy: 0.9815 - val_loss: 0.1565 - val_accuracy: 0.9702
#
# Epoch 00035: val_loss did not improve from 0.12176
# Epoch 36/200
# 9352/9352 [==============================] - 1106s 118ms/step - loss: 0.0918 - accuracy: 0.9817 - val_loss: 0.1537 - val_accuracy: 0.9696
#
# Epoch 00036: val_loss did not improve from 0.12176
# Epoch 37/200
# 9352/9352 [==============================] - 1107s 118ms/step - loss: 0.0847 - accuracy: 0.9810 - val_loss: 0.1508 - val_accuracy: 0.9710
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
#
# Epoch 00037: val_loss did not improve from 0.12176
# Epoch 38/200
# 9352/9352 [==============================] - 1109s 119ms/step - loss: 0.0877 - accuracy: 0.9814 - val_loss: 0.1519 - val_accuracy: 0.9694
#
# Epoch 00038: val_loss did not improve from 0.12176
# Epoch 39/200
# 9352/9352 [==============================] - 1098s 117ms/step - loss: 0.0880 - accuracy: 0.9816 - val_loss: 0.1533 - val_accuracy: 0.9708
#
# Epoch 00039: val_loss did not improve from 0.12176
# Epoch 40/200
# 9352/9352 [==============================] - 1100s 118ms/step - loss: 0.0928 - accuracy: 0.9813 - val_loss: 0.1546 - val_accuracy: 0.9704
#
# Epoch 00040: val_loss did not improve from 0.12176
# Epoch 41/200
# 9352/9352 [==============================] - 1097s 117ms/step - loss: 0.0902 - accuracy: 0.9812 - val_loss: 0.1488 - val_accuracy: 0.9694
#
# Epoch 00041: val_loss did not improve from 0.12176
# Epoch 42/200
# 9352/9352 [==============================] - 1099s 117ms/step - loss: 0.0866 - accuracy: 0.9821 - val_loss: 0.1522 - val_accuracy: 0.9702
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
#
# Epoch 00042: val_loss did not improve from 0.12176
# Epoch 43/200
# 9352/9352 [==============================] - 1102s 118ms/step - loss: 0.0906 - accuracy: 0.9814 - val_loss: 0.1491 - val_accuracy: 0.9708
#
# Epoch 00043: val_loss did not improve from 0.12176
# Epoch 44/200
# 9352/9352 [==============================] - 1103s 118ms/step - loss: 0.0910 - accuracy: 0.9811 - val_loss: 0.1505 - val_accuracy: 0.9706
#
# Epoch 00044: val_loss did not improve from 0.12176
# Epoch 45/200
# 9352/9352 [==============================] - 1097s 117ms/step - loss: 0.0859 - accuracy: 0.9813 - val_loss: 0.1550 - val_accuracy: 0.9702
#
# Epoch 00045: val_loss did not improve from 0.12176
# Epoch 46/200
# 9352/9352 [==============================] - 1097s 117ms/step - loss: 0.0863 - accuracy: 0.9816 - val_loss: 0.1491 - val_accuracy: 0.9694
#
# Epoch 00046: val_loss did not improve from 0.12176
# Epoch 47/200
# 9352/9352 [==============================] - 1094s 117ms/step - loss: 0.0871 - accuracy: 0.9815 - val_loss: 0.1520 - val_accuracy: 0.9706
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
#
# Epoch 00047: val_loss did not improve from 0.12176
# Epoch 48/200
# 9352/9352 [==============================] - 1096s 117ms/step - loss: 0.0842 - accuracy: 0.9810 - val_loss: 0.1513 - val_accuracy: 0.9704
#
# Epoch 00048: val_loss did not improve from 0.12176
# Epoch 49/200
# 9352/9352 [==============================] - 1101s 118ms/step - loss: 0.0859 - accuracy: 0.9809 - val_loss: 0.1498 - val_accuracy: 0.9696
#
# Epoch 00049: val_loss did not improve from 0.12176
# Epoch 50/200
# 9352/9352 [==============================] - 1094s 117ms/step - loss: 0.0878 - accuracy: 0.9809 - val_loss: 0.1492 - val_accuracy: 0.9704
#
# Epoch 00050: val_loss did not improve from 0.12176
# Epoch 51/200
# 9352/9352 [==============================] - 1093s 117ms/step - loss: 0.0888 - accuracy: 0.9812 - val_loss: 0.1509 - val_accuracy: 0.9700
#
# Epoch 00051: val_loss did not improve from 0.12176
# Epoch 52/200
# 9352/9352 [==============================] - 1091s 117ms/step - loss: 0.0886 - accuracy: 0.9817 - val_loss: 0.1476 - val_accuracy: 0.9700
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 9.99999943962493e-12.
#
# Epoch 00052: val_loss did not improve from 0.12176
# Epoch 00052: early stopping
# End Time : 2024-01-14 14:39:34.197767
# Running Time : 15:57:48.679828
# Done training

# %%
model.save(model_path)

# %%
import matplotlib.pylab as plt
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
# plt.plot(hist.history['val_loss'])
# plt.plot(hist.history['loss'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right', bbox_to_anchor=(1.3, 1))
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
# plt.plot(hist.history['val_loss'])
# plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right', bbox_to_anchor=(1.3, 1))
plt.show()

# %% [markdown]
# # test

# %%
test_X_csv_list = sorted(glob.glob(f'{DATA_PATH}/test/*.csv'))
print(len(test_X_csv_list))

test_X_npy_list = [csv_path.split('.csv')[0] + '_X.npy' for csv_path in test_X_csv_list]
test_Y_npy_list = [csv_path.split('.csv')[0] + '_Y.npy' for csv_path in test_X_csv_list]

test_X, test_Y = npy_load(test_X_npy_list, test_Y_npy_list)
# Out:
# 2500
# Total data len : 2500
#   0%|          | 0/2500 [00:00<?, ?it/s]
# X_data shape:  (4757, 64000, 1) 	 Y_data shape:  (4757, 1)

# %%
from keras.models import load_model

model = load_model(best_model_path)

# %%
predicted = model.predict(test_X, batch_size=64, verbose=1)
# Out:
# 75/75 [==============================] - 23s 277ms/step

# %%
predict_Y = predicted > 0.5

# %%
print(list(predict_Y).count(0))
print(list(predict_Y).count(1))
print('='*50)
print(list(test_Y).count(0))
print(list(test_Y).count(1))
# Out:
# 3049
# 1708
# ==================================================
# 3087
# 1670

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from imblearn.metrics import sensitivity_score, specificity_score

cm = confusion_matrix(test_Y, predict_Y)
sensitivity = sensitivity_score(test_Y, predict_Y)
specificity = specificity_score(test_Y, predict_Y)
accuracy = accuracy_score(test_Y, predict_Y)
precision = precision_score(test_Y, predict_Y)
f1 = f1_score(test_Y, predict_Y)

print(cm)
print(f'sensitivity : {round(sensitivity*100, 2)}')
print(f'specificity : {round(specificity*100, 2)}')
print(f'accuracy    : {round(accuracy*100, 2)}')
print(f'precision   : {round(precision*100, 2)}')
print(f'f1          : {round(f1*100, 2)}')
# Out:
# [[2949  138]
#  [ 100 1570]]
# sensitivity : 94.01
# specificity : 95.53
# accuracy    : 95.0
# precision   : 91.92
# f1          : 92.95

# %%
# model = se_resx1d.SEResNeXt(length, num_channel, model_width, cardinality=cardinality, ratio=reduction_ratio,
#                   problem_type=problem_type, output_nums=output_nums, pooling='avg', dropout_rate=False).SEResNeXt18()
