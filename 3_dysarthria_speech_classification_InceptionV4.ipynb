# %% [markdown]
# # 22 : 378

# %%
import os, glob, pickle, time
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam, SGD


from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle

import matplotlib.pyplot as plt

from tqdm import tqdm_notebook

import sys
path = os.path.abspath('../../')
print(path)
sys.path.append(path)
from CommonUtil import *

path = os.path.abspath('./models')
print(path)
sys.path.append(path)
import ResNet_1DCNN as res1d
import SE_ResNeXt_1DCNN as se_resx1d
import ResNeXt_1DCNN as resx1d
import Inception_ResNet_1DCNN as in_res1d
import Inception_1DCNN as incep1d

#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["CUDA_VISIBLE_DEVICES"]='3'
# os.environ["CUDA_VISIBLE_DEVICES"]='2'
#mirrored_strategy = tf.distribute.MirroredStrategy()
# Out:
# /home/gil/gcubme_ai3/Workspace/SB_MUN
# /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/models

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
LEARNING_RATE = 1e-4
EPOCHS = 200
BATCH_SIZE = 2
MODEL_NUM = 4
LOSS_FUNCTION = tf.keras.losses.MeanAbsoluteError()
LOSS_FUNCTION = 'binary_crossentropy'
METRICS = tf.keras.metrics.MeanSquaredError()
METRICS = ['accuracy']

TRAIN_SPLIT = 17
# Out:
# 2024-01-13 18:42:50.691328: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-13 18:42:51.238764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22282 MB memory:  -> device: 0, name: NVIDIA RTX A5000, pci bus id: 0000:af:00.0, compute capability: 8.6

# %%
length = 64000
model_name = 'InceptionV4'  # Modified DenseNet
model_width = 32  # Width of the Initial Layer, subsequent layers start from here
num_channel = 1  # Number of Channels in the Model
problem_type = 'Binary' # Classification or Regression
output_nums = 1  # Number of Class for Classification Problems, always '1' for Regression Problems
cardinality = 8
reduction_ratio = 4
# Build, Compile and Print Summary

# %%
DATA_PATH = os.path.abspath('./data/preproc2')
RESULT_DIR = os.path.abspath(f'./result/{model_name}')
MODEL_DIR = RESULT_DIR + '/model'

best_model_path = MODEL_DIR + '/best_model.h5'
model_path = MODEL_DIR + '/model.h5'

createFolder(MODEL_DIR)

print(DATA_PATH)
print(MODEL_DIR)
# Out:
# /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/data/preproc2
# /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/result/InceptionV4/model

# %%
train_X_csv_list = sorted(glob.glob(f'{DATA_PATH}/train/*.csv'))
validation_X_csv_list = sorted(glob.glob(f'{DATA_PATH}/validation/*.csv'))

print(len(train_X_csv_list))
print(len(validation_X_csv_list))
# Out:
# 20000
# 2500

# %%
train_X_npy_list = [csv_path.split('.csv')[0] + '_X.npy' for csv_path in train_X_csv_list]
train_Y_npy_list = [csv_path.split('.csv')[0] + '_Y.npy' for csv_path in train_X_csv_list]
validation_X_npy_list = [csv_path.split('.csv')[0] + '_X.npy' for csv_path in validation_X_csv_list]
validation_Y_npy_list = [csv_path.split('.csv')[0] + '_Y.npy' for csv_path in validation_X_csv_list]

# %%
train_X_npy_list, train_Y_npy_list = shuffle(train_X_npy_list, train_Y_npy_list)
validation_X_npy_list, validation_Y_npy_list = shuffle(validation_X_npy_list, validation_Y_npy_list)

# %%
def npy_load(X_path_list:list, Y_path_list:list):
    print(f'Total data len : {len(X_path_list)}')
    
    X_data = []
    Y_data = []
    data_paths = []
    
    for a in tqdm_notebook(range(len(X_path_list))):
#     for a in range(5):
        X_path = X_path_list[a]
        Y_path = Y_path_list[a]
    
#         print(f'{a}/{len(X_path_list)}\t==> {X_path}')
        
        X_npy = np.load(X_path)
        Y_npy = np.load(Y_path)
    
        X_data.extend(X_npy)
        Y_data.extend(Y_npy)
        data_paths.append(X_path)
        
    X_data, Y_data = shuffle(X_data, Y_data)
    
    X_data = np.array(X_data)
    Y_data = np.array(Y_data)
    X_data = np.expand_dims(X_data, axis=-1)
    Y_data = np.expand_dims(Y_data, axis=-1)
    print("X_data shape: ", X_data.shape, "\t Y_data shape: ", Y_data.shape)
    
    return X_data, Y_data # ,data_paths

# %%
train_X, train_Y = npy_load(train_X_npy_list, train_Y_npy_list)
validation_X, validation_Y = npy_load(validation_X_npy_list, validation_Y_npy_list)
# Out:
# Total data len : 20000
#   0%|          | 0/20000 [00:00<?, ?it/s]
# X_data shape:  (37407, 64000, 1) 	 Y_data shape:  (37407, 1)
# Total data len : 2500
#   0%|          | 0/2500 [00:00<?, ?it/s]
# X_data shape:  (4801, 64000, 1) 	 Y_data shape:  (4801, 1)

# %%
print(list(train_Y).count(0))
print(list(train_Y).count(1))
print('='*50)
print(list(validation_Y).count(0))
print(list(validation_Y).count(1))
print('='*50)
# Out:
# 24462
# 12945
# ==================================================
# 2889
# 1912
# ==================================================

# %% [markdown]
# # Model load

# %%
model = incep1d.Inception(length, num_channel, model_width, problem_type=problem_type,
                          output_nums=output_nums, pooling='avg', dropout_rate=False, auxilliary_outputs=False).Inception_v4()
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE), loss=LOSS_FUNCTION, metrics=METRICS)
model.summary()
# Out:
# Model: "Inception_v4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64000, 1)]   0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 31999, 32)    128         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 31999, 32)    128         conv1d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 31999, 32)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 31997, 32)    3104        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 31997, 32)    128         conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 31997, 32)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 31997, 64)    6208        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 31997, 64)    256         conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 31997, 64)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 15998, 96)    18528       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 15998, 96)    384         conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 15998, 96)    0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 15998, 64)    0           activation_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 15998, 160)   0           activation_3[0][0]
#                                                                  max_pooling1d[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 15998, 64)    10304       concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 15998, 64)    256         conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 15998, 64)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 15998, 64)    10304       concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 15998, 64)    28736       activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 15998, 64)    256         conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 15998, 64)    256         conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 15998, 64)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 15998, 64)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 15996, 96)    18528       activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 15996, 96)    18528       activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 15996, 96)    384         conv1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 15996, 96)    384         conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 15996, 96)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 15996, 96)    0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 15996, 192)   0           activation_5[0][0]
#                                                                  activation_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 15994, 192)   110784      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 15994, 192)   768         conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 15994, 192)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 7997, 192)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 23991, 192)   0           activation_9[0][0]
#                                                                  max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 23991, 64)    12352       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 23991, 64)    256         conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 23991, 64)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 23991, 64)    12352       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 23991, 96)    18528       activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 23991, 64)    256         conv1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 23991, 96)    384         conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 23991, 64)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 23991, 96)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# average_pooling1d (AveragePooli (None, 23991, 192)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 23991, 96)    18528       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 23991, 96)    30816       activation_11[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 23991, 96)    27744       activation_14[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 23991, 96)    18528       average_pooling1d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 23991, 96)    384         conv1d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 23991, 96)    384         conv1d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 23991, 96)    384         conv1d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 23991, 96)    384         conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 23991, 96)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 23991, 96)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 23991, 96)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 23991, 96)    0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# Inception_Block_A0 (Concatenate (None, 23991, 384)   0           activation_10[0][0]
#                                                                  activation_12[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_16[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 23991, 64)    24640       Inception_Block_A0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 23991, 64)    256         conv1d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 23991, 64)    0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 23991, 64)    24640       Inception_Block_A0[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 23991, 96)    18528       activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 23991, 64)    256         conv1d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 23991, 96)    384         conv1d_21[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 23991, 64)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 23991, 96)    0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_1 (AveragePoo (None, 23991, 384)   0           Inception_Block_A0[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 23991, 96)    36960       Inception_Block_A0[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 23991, 96)    30816       activation_18[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 23991, 96)    27744       activation_21[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 23991, 96)    36960       average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 23991, 96)    384         conv1d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 23991, 96)    384         conv1d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 23991, 96)    384         conv1d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 23991, 96)    384         conv1d_23[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 23991, 96)    0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 23991, 96)    0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 23991, 96)    0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 23991, 96)    0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# Inception_Block_A1 (Concatenate (None, 23991, 384)   0           activation_17[0][0]
#                                                                  activation_19[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 23991, 64)    24640       Inception_Block_A1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 23991, 64)    256         conv1d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 23991, 64)    0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 23991, 64)    24640       Inception_Block_A1[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 23991, 96)    18528       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 23991, 64)    256         conv1d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 23991, 96)    384         conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 23991, 64)    0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 23991, 96)    0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_2 (AveragePoo (None, 23991, 384)   0           Inception_Block_A1[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 23991, 96)    36960       Inception_Block_A1[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 23991, 96)    30816       activation_25[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 23991, 96)    27744       activation_28[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 23991, 96)    36960       average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 23991, 96)    384         conv1d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 23991, 96)    384         conv1d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 23991, 96)    384         conv1d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 23991, 96)    384         conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 23991, 96)    0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 23991, 96)    0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 23991, 96)    0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 23991, 96)    0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# Inception_Block_A2 (Concatenate (None, 23991, 384)   0           activation_24[0][0]
#                                                                  activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  activation_30[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 23991, 64)    24640       Inception_Block_A2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 23991, 64)    256         conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 23991, 64)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 23991, 64)    24640       Inception_Block_A2[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 23991, 96)    18528       activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 23991, 64)    256         conv1d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 23991, 96)    384         conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 23991, 64)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 23991, 96)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_3 (AveragePoo (None, 23991, 384)   0           Inception_Block_A2[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 23991, 96)    36960       Inception_Block_A2[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 23991, 96)    30816       activation_32[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 23991, 96)    27744       activation_35[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 23991, 96)    36960       average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 23991, 96)    384         conv1d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 23991, 96)    384         conv1d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 23991, 96)    384         conv1d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 23991, 96)    384         conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 23991, 96)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 23991, 96)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 23991, 96)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 23991, 96)    0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# Inception_Block_A3 (Concatenate (None, 23991, 384)   0           activation_31[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_36[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 23991, 192)   73920       Inception_Block_A3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 23991, 192)   768         conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 23991, 192)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 23991, 64)    24640       Inception_Block_A3[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 23991, 224)   129248      activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 23991, 64)    256         conv1d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 23991, 224)   896         conv1d_41[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 23991, 64)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 23991, 224)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 11996, 384)   74112       activation_38[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 11996, 256)   172288      activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 11996, 384)   1536        conv1d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 11996, 256)   1024        conv1d_42[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 11996, 384)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 11996, 256)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 11996, 384)   0           Inception_Block_A3[0][0]
# __________________________________________________________________________________________________
# Reduction_Block_1 (Concatenate) (None, 11996, 1024)  0           activation_39[0][0]
#                                                                  activation_42[0][0]
#                                                                  max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 11996, 192)   196800      Reduction_Block_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 11996, 192)   768         conv1d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 11996, 192)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 11996, 192)   196800      Reduction_Block_1[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 11996, 224)   301280      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 11996, 192)   768         conv1d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 11996, 224)   896         conv1d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 11996, 192)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 11996, 224)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_4 (AveragePoo (None, 11996, 1024)  0           Reduction_Block_1[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 11996, 384)   393600      Reduction_Block_1[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 11996, 256)   344320      activation_44[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 11996, 256)   401664      activation_47[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 11996, 128)   131200      average_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 11996, 384)   1536        conv1d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 11996, 256)   1024        conv1d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 11996, 256)   1024        conv1d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 11996, 128)   512         conv1d_49[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 11996, 384)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 11996, 256)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 11996, 256)   0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 11996, 128)   0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# Inception_Block_B0 (Concatenate (None, 11996, 1024)  0           activation_43[0][0]
#                                                                  activation_45[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 11996, 192)   196800      Inception_Block_B0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 11996, 192)   768         conv1d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 11996, 192)   0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 11996, 192)   196800      Inception_Block_B0[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 11996, 224)   301280      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 11996, 192)   768         conv1d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 11996, 224)   896         conv1d_54[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 11996, 192)   0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 11996, 224)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_5 (AveragePoo (None, 11996, 1024)  0           Inception_Block_B0[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 11996, 384)   393600      Inception_Block_B0[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 11996, 256)   344320      activation_51[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 11996, 256)   401664      activation_54[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, 11996, 128)   131200      average_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 11996, 384)   1536        conv1d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 11996, 256)   1024        conv1d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 11996, 256)   1024        conv1d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 11996, 128)   512         conv1d_56[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 11996, 384)   0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 11996, 256)   0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 11996, 256)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 11996, 128)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# Inception_Block_B1 (Concatenate (None, 11996, 1024)  0           activation_50[0][0]
#                                                                  activation_52[0][0]
#                                                                  activation_55[0][0]
#                                                                  activation_56[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, 11996, 192)   196800      Inception_Block_B1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 11996, 192)   768         conv1d_60[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 11996, 192)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv1d_58 (Conv1D)              (None, 11996, 192)   196800      Inception_Block_B1[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, 11996, 224)   301280      activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 11996, 192)   768         conv1d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 11996, 224)   896         conv1d_61[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 11996, 192)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 11996, 224)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_6 (AveragePoo (None, 11996, 1024)  0           Inception_Block_B1[0][0]
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, 11996, 384)   393600      Inception_Block_B1[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, 11996, 256)   344320      activation_58[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, 11996, 256)   401664      activation_61[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 11996, 128)   131200      average_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 11996, 384)   1536        conv1d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 11996, 256)   1024        conv1d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 11996, 256)   1024        conv1d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 11996, 128)   512         conv1d_63[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 11996, 384)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 11996, 256)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 11996, 256)   0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 11996, 128)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# Inception_Block_B2 (Concatenate (None, 11996, 1024)  0           activation_57[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_62[0][0]
#                                                                  activation_63[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 11996, 192)   196800      Inception_Block_B2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 11996, 192)   768         conv1d_67[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 11996, 192)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 11996, 192)   196800      Inception_Block_B2[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 11996, 224)   301280      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 11996, 192)   768         conv1d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 11996, 224)   896         conv1d_68[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 11996, 192)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 11996, 224)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_7 (AveragePoo (None, 11996, 1024)  0           Inception_Block_B2[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 11996, 384)   393600      Inception_Block_B2[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 11996, 256)   344320      activation_65[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 11996, 256)   401664      activation_68[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 11996, 128)   131200      average_pooling1d_7[0][0]
# ...
# max_pooling1d_3 (MaxPooling1D)  (None, 5998, 1024)   0           Inception_Block_B6[0][0]
# __________________________________________________________________________________________________
# Reduction_Block_2 (Concatenate) (None, 5998, 1536)   0           activation_93[0][0]
#                                                                  activation_96[0][0]
#                                                                  max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_100 (Conv1D)             (None, 5998, 384)    590208      Reduction_Block_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 5998, 384)    1536        conv1d_100[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 5998, 384)    0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv1d_98 (Conv1D)              (None, 5998, 384)    590208      Reduction_Block_2[0][0]
# __________________________________________________________________________________________________
# conv1d_101 (Conv1D)             (None, 5998, 512)    590336      activation_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 5998, 384)    1536        conv1d_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 5998, 512)    2048        conv1d_101[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 5998, 384)    0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 5998, 512)    0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_11 (AveragePo (None, 5998, 1536)   0           Reduction_Block_2[0][0]
# __________________________________________________________________________________________________
# conv1d_97 (Conv1D)              (None, 5998, 256)    393472      Reduction_Block_2[0][0]
# __________________________________________________________________________________________________
# conv1d_99 (Conv1D)              (None, 5998, 512)    590336      activation_98[0][0]
# __________________________________________________________________________________________________
# conv1d_102 (Conv1D)             (None, 5998, 512)    786944      activation_101[0][0]
# __________________________________________________________________________________________________
# conv1d_103 (Conv1D)             (None, 5998, 256)    393472      average_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 5998, 256)    1024        conv1d_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 5998, 512)    2048        conv1d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 5998, 512)    2048        conv1d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 5998, 256)    1024        conv1d_103[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 5998, 256)    0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 5998, 512)    0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 5998, 512)    0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 5998, 256)    0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# Inception_Block_C0 (Concatenate (None, 5998, 1536)   0           activation_97[0][0]
#                                                                  activation_99[0][0]
#                                                                  activation_102[0][0]
#                                                                  activation_103[0][0]
# __________________________________________________________________________________________________
# conv1d_107 (Conv1D)             (None, 5998, 384)    590208      Inception_Block_C0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 5998, 384)    1536        conv1d_107[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 5998, 384)    0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv1d_105 (Conv1D)             (None, 5998, 384)    590208      Inception_Block_C0[0][0]
# __________________________________________________________________________________________________
# conv1d_108 (Conv1D)             (None, 5998, 512)    590336      activation_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 5998, 384)    1536        conv1d_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 5998, 512)    2048        conv1d_108[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 5998, 384)    0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 5998, 512)    0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_12 (AveragePo (None, 5998, 1536)   0           Inception_Block_C0[0][0]
# __________________________________________________________________________________________________
# conv1d_104 (Conv1D)             (None, 5998, 256)    393472      Inception_Block_C0[0][0]
# __________________________________________________________________________________________________
# conv1d_106 (Conv1D)             (None, 5998, 512)    590336      activation_105[0][0]
# __________________________________________________________________________________________________
# conv1d_109 (Conv1D)             (None, 5998, 512)    786944      activation_108[0][0]
# __________________________________________________________________________________________________
# conv1d_110 (Conv1D)             (None, 5998, 256)    393472      average_pooling1d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 5998, 256)    1024        conv1d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 5998, 512)    2048        conv1d_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 5998, 512)    2048        conv1d_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 5998, 256)    1024        conv1d_110[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 5998, 256)    0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 5998, 512)    0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 5998, 512)    0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 5998, 256)    0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# Inception_Block_C1 (Concatenate (None, 5998, 1536)   0           activation_104[0][0]
#                                                                  activation_106[0][0]
#                                                                  activation_109[0][0]
#                                                                  activation_110[0][0]
# __________________________________________________________________________________________________
# conv1d_114 (Conv1D)             (None, 5998, 384)    590208      Inception_Block_C1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 5998, 384)    1536        conv1d_114[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 5998, 384)    0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv1d_112 (Conv1D)             (None, 5998, 384)    590208      Inception_Block_C1[0][0]
# __________________________________________________________________________________________________
# conv1d_115 (Conv1D)             (None, 5998, 512)    590336      activation_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 5998, 384)    1536        conv1d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 5998, 512)    2048        conv1d_115[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 5998, 384)    0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 5998, 512)    0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_13 (AveragePo (None, 5998, 1536)   0           Inception_Block_C1[0][0]
# __________________________________________________________________________________________________
# conv1d_111 (Conv1D)             (None, 5998, 256)    393472      Inception_Block_C1[0][0]
# __________________________________________________________________________________________________
# conv1d_113 (Conv1D)             (None, 5998, 512)    590336      activation_112[0][0]
# __________________________________________________________________________________________________
# conv1d_116 (Conv1D)             (None, 5998, 512)    786944      activation_115[0][0]
# __________________________________________________________________________________________________
# conv1d_117 (Conv1D)             (None, 5998, 256)    393472      average_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 5998, 256)    1024        conv1d_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 5998, 512)    2048        conv1d_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 5998, 512)    2048        conv1d_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 5998, 256)    1024        conv1d_117[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 5998, 256)    0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 5998, 512)    0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 5998, 512)    0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 5998, 256)    0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# Inception_Block_C2 (Concatenate (None, 5998, 1536)   0           activation_111[0][0]
#                                                                  activation_113[0][0]
#                                                                  activation_116[0][0]
#                                                                  activation_117[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 1536)         0           Inception_Block_C2[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1536)         0           global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            1537        flatten[0][0]
# ==================================================================================================
# Total params: 28,558,465
# Trainable params: 28,507,457
# Non-trainable params: 51,008
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, History, ReduceLROnPlateau, EarlyStopping

checkpointer = ModelCheckpoint(best_model_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, verbose=1, min_delta=1e-8)
earlystopper = EarlyStopping(monitor='val_loss', patience=30, verbose=1)
callbacks_list = [reduce_lr, checkpointer, earlystopper]

# %% [markdown]
# # train

# %%
from datetime import datetime
startTime = datetime.now()

print('Start Time : {0}'.format(startTime))
###############################################################################################

hist = model.fit(train_X, train_Y, 
                 batch_size=BATCH_SIZE, epochs=EPOCHS, verbose=1, 
                 validation_data = (validation_X, validation_Y), 
                 callbacks=callbacks_list)

################################################################################################

endTime = datetime.now()
runTime = endTime - startTime

print('End Time : {0}'.format(endTime))
print('Running Time : ' + str(runTime))

print('Done training')
# Out:
# Start Time : 2024-01-13 18:46:51.554058
# 2024-01-13 18:46:51.559042: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 9576192000 exceeds 10% of free system memory.
# 2024-01-13 18:46:59.441261: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 9576192000 exceeds 10% of free system memory.
# 2024-01-13 18:47:05.012617: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2024-01-13 18:47:25.376392: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8201
# 2024-01-13 18:47:29.009394: I tensorflow/stream_executor/cuda/cuda_blas.cc:1760] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 18704/18704 [==============================] - 9406s 501ms/step - loss: 0.2329 - accuracy: 0.9075 - val_loss: 0.2181 - val_accuracy: 0.9181
#
# Epoch 00001: val_loss improved from inf to 0.21815, saving model to /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/result/InceptionV4/model/best_model.h5
# Epoch 2/200
# 18704/18704 [==============================] - 9325s 499ms/step - loss: 0.1275 - accuracy: 0.9540 - val_loss: 0.1739 - val_accuracy: 0.9319
#
# Epoch 00002: val_loss improved from 0.21815 to 0.17388, saving model to /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/result/InceptionV4/model/best_model.h5
# Epoch 3/200
# 18704/18704 [==============================] - 9403s 503ms/step - loss: 0.1011 - accuracy: 0.9646 - val_loss: 0.2718 - val_accuracy: 0.9344
#
# Epoch 00003: val_loss did not improve from 0.17388
# Epoch 4/200
# 18704/18704 [==============================] - 9404s 503ms/step - loss: 0.0893 - accuracy: 0.9701 - val_loss: 0.1388 - val_accuracy: 0.9536
#
# Epoch 00004: val_loss improved from 0.17388 to 0.13878, saving model to /home/gil/gcubme_ai3/Workspace/SB_MUN/9_NIA_46_dysarthria/1_source_abstract/result/InceptionV4/model/best_model.h5
# Epoch 5/200
# 18704/18704 [==============================] - 9403s 503ms/step - loss: 0.0860 - accuracy: 0.9715 - val_loss: 0.1729 - val_accuracy: 0.9375
#
# Epoch 00005: val_loss did not improve from 0.13878
# Epoch 6/200
# 18704/18704 [==============================] - 9395s 502ms/step - loss: 0.0804 - accuracy: 0.9732 - val_loss: 0.2731 - val_accuracy: 0.9225
#
# Epoch 00006: val_loss did not improve from 0.13878
# Epoch 7/200
# 18704/18704 [==============================] - 9351s 500ms/step - loss: 0.0738 - accuracy: 0.9758 - val_loss: 0.1417 - val_accuracy: 0.9527
#
# Epoch 00007: val_loss did not improve from 0.13878
# Epoch 8/200
# 18704/18704 [==============================] - 9309s 498ms/step - loss: 0.0720 - accuracy: 0.9764 - val_loss: 0.1656 - val_accuracy: 0.9563
#
# Epoch 00008: val_loss did not improve from 0.13878
# Epoch 9/200
# 18704/18704 [==============================] - 9220s 493ms/step - loss: 0.0687 - accuracy: 0.9774 - val_loss: 0.6000 - val_accuracy: 0.7898
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 00009: val_loss did not improve from 0.13878
# Epoch 10/200
# 18704/18704 [==============================] - 9197s 492ms/step - loss: 0.0511 - accuracy: 0.9838 - val_loss: 0.2083 - val_accuracy: 0.9413
#
# Epoch 00010: val_loss did not improve from 0.13878
# Epoch 11/200
# 18704/18704 [==============================] - 9197s 492ms/step - loss: 0.0450 - accuracy: 0.9858 - val_loss: 0.1501 - val_accuracy: 0.9660
#
# Epoch 00011: val_loss did not improve from 0.13878
# Epoch 12/200
# 18704/18704 [==============================] - 9196s 492ms/step - loss: 0.0445 - accuracy: 0.9856 - val_loss: 0.1553 - val_accuracy: 0.9569
#
# Epoch 00012: val_loss did not improve from 0.13878
# Epoch 13/200
# 18704/18704 [==============================] - 9195s 492ms/step - loss: 0.0419 - accuracy: 0.9867 - val_loss: 0.1468 - val_accuracy: 0.9633
#
# Epoch 00013: val_loss did not improve from 0.13878
# Epoch 14/200
# 18704/18704 [==============================] - 9201s 492ms/step - loss: 0.0409 - accuracy: 0.9868 - val_loss: 0.1690 - val_accuracy: 0.9573
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
#
# Epoch 00014: val_loss did not improve from 0.13878
# Epoch 15/200
# 18704/18704 [==============================] - 9201s 492ms/step - loss: 0.0385 - accuracy: 0.9872 - val_loss: 0.1704 - val_accuracy: 0.9596
#
# Epoch 00015: val_loss did not improve from 0.13878
# Epoch 16/200
# 18704/18704 [==============================] - 9200s 492ms/step - loss: 0.0389 - accuracy: 0.9876 - val_loss: 0.1592 - val_accuracy: 0.9610
#
# Epoch 00016: val_loss did not improve from 0.13878
# Epoch 17/200
# 18704/18704 [==============================] - 9206s 492ms/step - loss: 0.0385 - accuracy: 0.9877 - val_loss: 0.1619 - val_accuracy: 0.9617
#
# Epoch 00017: val_loss did not improve from 0.13878
# Epoch 18/200
# 18704/18704 [==============================] - 9204s 492ms/step - loss: 0.0376 - accuracy: 0.9877 - val_loss: 0.1571 - val_accuracy: 0.9619
#
# Epoch 00018: val_loss did not improve from 0.13878
# Epoch 19/200
# 18704/18704 [==============================] - 9201s 492ms/step - loss: 0.0369 - accuracy: 0.9884 - val_loss: 0.1569 - val_accuracy: 0.9619
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 9.999999974752428e-08.
#
# Epoch 00019: val_loss did not improve from 0.13878
# Epoch 20/200
# 18704/18704 [==============================] - 9202s 492ms/step - loss: 0.0381 - accuracy: 0.9878 - val_loss: 0.1611 - val_accuracy: 0.9623
#
# Epoch 00020: val_loss did not improve from 0.13878
# Epoch 21/200
# 18704/18704 [==============================] - 9202s 492ms/step - loss: 0.0372 - accuracy: 0.9884 - val_loss: 0.1807 - val_accuracy: 0.9604
#
# Epoch 00021: val_loss did not improve from 0.13878
# Epoch 22/200
# 18704/18704 [==============================] - 9200s 492ms/step - loss: 0.0370 - accuracy: 0.9878 - val_loss: 0.1559 - val_accuracy: 0.9610
#
# Epoch 00022: val_loss did not improve from 0.13878
# Epoch 23/200
# 18704/18704 [==============================] - 9213s 493ms/step - loss: 0.0375 - accuracy: 0.9877 - val_loss: 0.1583 - val_accuracy: 0.9621
#
# Epoch 00023: val_loss did not improve from 0.13878
# Epoch 24/200
# 18704/18704 [==============================] - 9206s 492ms/step - loss: 0.0364 - accuracy: 0.9881 - val_loss: 0.1705 - val_accuracy: 0.9619
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.0000000116860975e-08.
#
# Epoch 00024: val_loss did not improve from 0.13878
# Epoch 25/200
# 18704/18704 [==============================] - 9197s 492ms/step - loss: 0.0370 - accuracy: 0.9884 - val_loss: 0.1647 - val_accuracy: 0.9615
#
# Epoch 00025: val_loss did not improve from 0.13878
# Epoch 26/200
# 18704/18704 [==============================] - 9207s 492ms/step - loss: 0.0374 - accuracy: 0.9880 - val_loss: 0.1652 - val_accuracy: 0.9600
#
# Epoch 00026: val_loss did not improve from 0.13878
# Epoch 27/200
# 18704/18704 [==============================] - 9216s 493ms/step - loss: 0.0365 - accuracy: 0.9888 - val_loss: 0.1633 - val_accuracy: 0.9623
#
# Epoch 00027: val_loss did not improve from 0.13878
# Epoch 28/200
# 18704/18704 [==============================] - 9231s 494ms/step - loss: 0.0378 - accuracy: 0.9876 - val_loss: 0.1626 - val_accuracy: 0.9621
#
# Epoch 00028: val_loss did not improve from 0.13878
# Epoch 29/200
# 18704/18704 [==============================] - 9229s 493ms/step - loss: 0.0366 - accuracy: 0.9886 - val_loss: 0.1583 - val_accuracy: 0.9617
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 9.999999939225292e-10.
#
# Epoch 00029: val_loss did not improve from 0.13878
# Epoch 30/200
# 18704/18704 [==============================] - 9232s 494ms/step - loss: 0.0367 - accuracy: 0.9883 - val_loss: 0.1588 - val_accuracy: 0.9621
#
# Epoch 00030: val_loss did not improve from 0.13878
# Epoch 31/200
# 18704/18704 [==============================] - 9236s 494ms/step - loss: 0.0378 - accuracy: 0.9884 - val_loss: 0.1640 - val_accuracy: 0.9608
#
# Epoch 00031: val_loss did not improve from 0.13878
# Epoch 32/200
# 18704/18704 [==============================] - 9232s 494ms/step - loss: 0.0367 - accuracy: 0.9881 - val_loss: 0.1565 - val_accuracy: 0.9627
#
# Epoch 00032: val_loss did not improve from 0.13878
# Epoch 33/200
# 18704/18704 [==============================] - 9227s 493ms/step - loss: 0.0374 - accuracy: 0.9877 - val_loss: 0.1673 - val_accuracy: 0.9615
#
# Epoch 00033: val_loss did not improve from 0.13878
# Epoch 34/200
# 18704/18704 [==============================] - 9210s 492ms/step - loss: 0.0354 - accuracy: 0.9889 - val_loss: 0.1695 - val_accuracy: 0.9615
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 9.999999717180686e-11.
#
# Epoch 00034: val_loss did not improve from 0.13878
# Epoch 00034: early stopping
# End Time : 2024-01-17 10:08:16.514258
# Running Time : 3 days, 15:21:24.960200
# Done training

# %%
model.save(model_path)

# %%
import matplotlib.pylab as plt
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
# plt.plot(hist.history['val_loss'])
# plt.plot(hist.history['loss'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right', bbox_to_anchor=(1.3, 1))
plt.show()

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
# plt.plot(hist.history['val_loss'])
# plt.plot(hist.history['loss'])
plt.title('Model Loss')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right', bbox_to_anchor=(1.3, 1))
plt.show()

# %% [markdown]
# # test

# %%
test_X_csv_list = sorted(glob.glob(f'{DATA_PATH}/test/*.csv'))
print(len(test_X_csv_list))

test_X_npy_list = [csv_path.split('.csv')[0] + '_X.npy' for csv_path in test_X_csv_list]
test_Y_npy_list = [csv_path.split('.csv')[0] + '_Y.npy' for csv_path in test_X_csv_list]

test_X, test_Y = npy_load(test_X_npy_list, test_Y_npy_list)
# Out:
# 2500
# Total data len : 2500
#   0%|          | 0/2500 [00:00<?, ?it/s]
# X_data shape:  (4757, 64000, 1) 	 Y_data shape:  (4757, 1)

# %%
from keras.models import load_model

model = load_model(best_model_path)

# %%
predicted = model.predict(test_X, batch_size=64, verbose=1)
# Out:
# 75/75 [==============================] - 322s 4s/step

# %%
predict_Y = predicted > 0.5

# %%
print(list(predict_Y).count(0))
print(list(predict_Y).count(1))
print('='*50)
print(list(test_Y).count(0))
print(list(test_Y).count(1))
# Out:
# 2990
# 1767
# ==================================================
# 3087
# 1670

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from imblearn.metrics import sensitivity_score, specificity_score

cm = confusion_matrix(test_Y, predict_Y)
sensitivity = sensitivity_score(test_Y, predict_Y)
specificity = specificity_score(test_Y, predict_Y)
accuracy = accuracy_score(test_Y, predict_Y)
precision = precision_score(test_Y, predict_Y)
f1 = f1_score(test_Y, predict_Y)

print(cm)
print(f'sensitivity : {round(sensitivity*100, 2)}')
print(f'specificity : {round(specificity*100, 2)}')
print(f'accuracy    : {round(accuracy*100, 2)}')
print(f'precision   : {round(precision*100, 2)}')
print(f'f1          : {round(f1*100, 2)}')
# Out:
# [[2887  200]
#  [ 103 1567]]
# sensitivity : 93.83
# specificity : 93.52
# accuracy    : 93.63
# precision   : 88.68
# f1          : 91.18

# %%
# model = incep1d.Inception(length, num_channel, model_width, problem_type=problem_type,
#                           output_nums=output_nums, pooling='avg', dropout_rate=False, auxilliary_outputs=False).Inception_v4()
